# %% [markdown]
# # Week 1: Orientation & Setup
# **Course:** Data Science & AI
# **Assignment 1:** Load and Display Dataset
# **Student:** Mehreen Muhammad Majid
# **Project:** Student Performance Prediction
#
# ---
#
# ### Objective
# The goal of this assignment is to load a dataset from Kaggle and display the first 10 rows using Python (Pandas).
# This demonstrates basic setup, data loading, and environment readiness for upcoming weeks.
#
# ---

# %%
# Assignment 1 - Week 1
# Student Performance Dataset Exploration

# Step 1: Import libraries
import pandas as pd

# Step 2: Load the dataset
df = pd.read_csv("Students Performance Dataset.csv")  

# Step 3: Display first 10 rows
df.head(10)
# Out:
#   Student_ID First_Name Last_Name                    Email  Gender  Age  \
# 0      S1000       Omar  Williams  student0@university.com  Female   22
# 1      S1001      Maria     Brown  student1@university.com    Male   18
# 2      S1002      Ahmed     Jones  student2@university.com    Male   24
# 3      S1003       Omar  Williams  student3@university.com  Female   24
# 4      S1004       John     Smith  student4@university.com  Female   23
# 5      S1005       Liam     Brown  student5@university.com    Male   21
# 6      S1006      Ahmed     Jones  student6@university.com    Male   24
# 7      S1007      Ahmed     Smith  student7@university.com    Male   19
# 8      S1008       Omar     Smith  student8@university.com  Female   21
# 9      S1009       Sara     Smith  student9@university.com  Female   22
#
#     Department  Attendance (%)  Midterm_Score  Final_Score  ...  \
# 0  Mathematics           97.36          40.61        59.61  ...
# ...

# %%
df.head(10).style.set_table_styles([
    {'selector': 'thead th', 'props': [('background-color', '#2E86C1'), ('color', 'white'), ('font-size', '14px')]},
    {'selector': 'tbody td', 'props': [('font-size', '13px')]}
])
# Out:
# <style type="text/css">
# #T_28391 thead th {
#   background-color: #2E86C1;
#   color: white;
#   font-size: 14px;
# }
# #T_28391 tbody td {
#   font-size: 13px;
# }
# </style>
# <table id="T_28391">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_28391_level0_col0" class="col_heading level0 col0" >Student_ID</th>
#       <th id="T_28391_level0_col1" class="col_heading level0 col1" >First_Name</th>
#       <th id="T_28391_level0_col2" class="col_heading level0 col2" >Last_Name</th>
#       <th id="T_28391_level0_col3" class="col_heading level0 col3" >Email</th>
#       <th id="T_28391_level0_col4" class="col_heading level0 col4" >Gender</th>
#       <th id="T_28391_level0_col5" class="col_heading level0 col5" >Age</th>
#       <th id="T_28391_level0_col6" class="col_heading level0 col6" >Department</th>
#       <th id="T_28391_level0_col7" class="col_heading level0 col7" >Attendance (%)</th>
# ...

# %% [markdown]
# ---
#
# ### Summary
# In this assignment, the dataset was successfully loaded and the first 10 rows were displayed using Pandas.
# This confirms that the Python environment is working correctly and ready for further data analysis tasks.
#
# ---
